# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.1'

# %% [markdown]
# # Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
df.shape
# Out:
# (891, 12)

# %%
df[df['Age']>50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q4. How do you rename columns in a Pandas DataFrame?

# %%
df.rename(columns = {'Pclass':'PassengerClass'},inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # Q5. How do you drop columns in a Pandas DataFrame?

# %%
df_copy=df.copy(deep=True)
df_copy.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_copy.drop(['Ticket'],axis=1)
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0              1         0               3
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 4              5         0               3
# ..           ...       ...             ...
# 886          887         0               2
# 887          888         1               1
# 888          889         0               3
# 889          890         1               1
# 890          891         0               3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df_copy.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
df.PassengerClass.unique()
# Out:
# array([3, 1, 2])

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
df.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# PassengerClass      0
# Name                0
# Sex                 0
# Age               177
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# dtype: int64

# %% [markdown]
# # Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df_copy.fillna({"Age":df_copy['Age'].mean()},inplace=True)

# %%
df_copy.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_copy.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# PassengerClass      0
# Name                0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# dtype: int64

# %% [markdown]
# # Q9. How do you concatenate two Pandas DataFrames?

# %%
df_concat=pd.concat([df,df_copy],axis=1)
#concat along the column

# %%
df_concat.head()
# Out:
#    PassengerId  Survived PassengerClass  \
# 0            1         0              3
# 1            2         1              1
# 2            3         1              3
# 3            4         1              1
# 4            5         0              3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#   Parch            Ticket     Fare  ... PassengerClass  \
# 0     0         A/5 21171   7.2500  ...              3
# 1     0          PC 17599  71.2833  ...              1
# 2     0  STON/O2. 3101282   7.9250  ...              3
# ...

# %% [markdown]
# # Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
df_merged=df.merge(df_copy,on='PassengerId')
df_merged.head()
# Out:
#    PassengerId  Survived_x  PassengerClass_x  \
# 0            1           0                 3
# 1            2           1                 1
# 2            3           1                 3
# 3            4           1                 1
# 4            5           0                 3
#
#                                               Name_x   Sex_x  Age_x  SibSp_x  \
# 0                            Braund, Mr. Owen Harris    male   22.0        1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0        1
# 2                             Heikkinen, Miss. Laina  female   26.0        0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0        1
# 4                           Allen, Mr. William Henry    male   35.0        0
#
#    Parch_x          Ticket_x   Fare_x  ... PassengerClass_y  \
# 0        0         A/5 21171   7.2500  ...                3
# 1        0          PC 17599  71.2833  ...                1
# ...

# %% [markdown]
# # Q15. How do you create a copy of a Pandas DataFrame?

# %%
df_copy=df.copy(deep=True)

# %%
df_copy.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_copy.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# PassengerClass      0
# Name                0
# Sex                 0
# Age               177
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2
# dtype: int64

# %% [markdown]
# # Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
df.groupby(by=['PassengerClass'])['Age'].mean()
# Out:
# PassengerClass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# # Q12. How do you pivot a Pandas DataFrame?

# %% [markdown]
# # Q13. How do you change the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
# Out:
# PassengerId         int64
# Survived            int64
# PassengerClass      int64
# Name               object
# Sex                object
# Age               float64
# SibSp               int64
# Parch               int64
# Ticket             object
# Fare              float64
# Cabin              object
# Embarked           object
# dtype: object

# %%
convert_type={'SibSp':float}
new_df=df.astype(convert_type)

# %%
new_df.dtypes
# Out:
# PassengerId         int64
# Survived            int64
# PassengerClass      int64
# Name               object
# Sex                object
# Age               float64
# SibSp             float64
# Parch               int64
# Ticket             object
# Fare              float64
# Cabin              object
# Embarked           object
# dtype: object

# %% [markdown]
# # Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
df_sorted= df.sort_values(by='Name')
df_sorted.head()
# Out:
#      PassengerId  Survived  PassengerClass  \
# 845          846         0               3
# 746          747         0               3
# 279          280         1               3
# 308          309         0               2
# 874          875         1               2
#
#                                       Name     Sex   Age  SibSp  Parch  \
# 845                    Abbing, Mr. Anthony    male  42.0      0      0
# 746            Abbott, Mr. Rossmore Edward    male  16.0      1      1
# 279       Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1      1
# 308                    Abelson, Mr. Samuel    male  30.0      1      0
# 874  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1      0
#
#         Ticket   Fare Cabin Embarked
# 845  C.A. 5547   7.55   NaN        S
# 746  C.A. 2673  20.25   NaN        S
# 279  C.A. 2673  20.25   NaN        S
# 308  P/PP 3381  24.00   NaN        C
# 874  P/PP 3381  24.00   NaN        C

# %% [markdown]
# # Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
df_age = df[(df['Age']>22) & (df['Age']<35)]

# %%
df_age.head()
# Out:
#     PassengerId  Survived  PassengerClass  \
# 2             3         1               3
# 8             9         1               3
# 18           19         0               3
# 21           22         1               2
# 23           24         1               1
#
#                                                  Name     Sex   Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 8       2            347742  11.1333   NaN        S
# 18      0            345763  18.0000   NaN        S
# ...

# %%
df_age['Age'].min()
# Out:
# 23.0

# %%
df_age['Age'].max()
# Out:
# 34.5

# %% [markdown]
# # Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df.groupby(by=['PassengerClass'])['Fare'].mean()
# Out:
# PassengerClass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# # Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df['Fare'].std()
# Out:
# 49.693428597180905

# %% [markdown]
# # Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %% [markdown]
# # Q20. How do you select specific columns in a DataFrame using their labels?

# %% [markdown]
# # Q21. How do you select specific rows in a DataFrame using their indexes?

# %% [markdown]
# # Q22. How do you sort a DataFrame by a specific column?

# %%
df_sorted= df.sort_values(by='Name')
df_sorted.head()
# Out:
#      PassengerId  Survived  PassengerClass  \
# 845          846         0               3
# 746          747         0               3
# 279          280         1               3
# 308          309         0               2
# 874          875         1               2
#
#                                       Name     Sex   Age  SibSp  Parch  \
# 845                    Abbing, Mr. Anthony    male  42.0      0      0
# 746            Abbott, Mr. Rossmore Edward    male  16.0      1      1
# 279       Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1      1
# 308                    Abelson, Mr. Samuel    male  30.0      1      0
# 874  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1      0
#
#         Ticket   Fare Cabin Embarked
# 845  C.A. 5547   7.55   NaN        S
# 746  C.A. 2673  20.25   NaN        S
# 279  C.A. 2673  20.25   NaN        S
# 308  P/PP 3381  24.00   NaN        C
# 874  P/PP 3381  24.00   NaN        C

# %% [markdown]
# # Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
def older(age):
    if(age>60):
        return 'Old'
    else:
        return 'young'
    
df['Age Group'] = df['Age'].map(older)

# %%
df.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Age Group
# 0      0         A/5 21171   7.2500   NaN        S     young
# 1      0          PC 17599  71.2833   C85        C     young
# 2      0  STON/O2. 3101282   7.9250   NaN        S     young
# ...

# %% [markdown]
# # Q24. How do you remove duplicates from a DataFrame?

# %%
df_sorted.head()
# Out:
#      PassengerId  Survived  PassengerClass  \
# 845          846         0               3
# 746          747         0               3
# 279          280         1               3
# 308          309         0               2
# 874          875         1               2
#
#                                       Name     Sex   Age  SibSp  Parch  \
# 845                    Abbing, Mr. Anthony    male  42.0      0      0
# 746            Abbott, Mr. Rossmore Edward    male  16.0      1      1
# 279       Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1      1
# 308                    Abelson, Mr. Samuel    male  30.0      1      0
# 874  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1      0
#
#         Ticket   Fare Cabin Embarked
# 845  C.A. 5547   7.55   NaN        S
# 746  C.A. 2673  20.25   NaN        S
# 279  C.A. 2673  20.25   NaN        S
# 308  P/PP 3381  24.00   NaN        C
# 874  P/PP 3381  24.00   NaN        C

# %%
df_dup= df_sorted.drop_duplicates(subset='Ticket',keep=False)

# %%
df_dup.shape
# Out:
# (547, 12)

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Q25. What is the difference between .loc and .iloc in Pandas?
